# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-библиотек-и-предобработка-данных" data-toc-modified-id="Загрузка-библиотек-и-предобработка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка библиотек и предобработка данных</a></span></li><li><span><a href="#Тематический-анализ-и-частотный-анализ-слов" data-toc-modified-id="Тематический-анализ-и-частотный-анализ-слов-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Тематический анализ и частотный анализ слов</a></span></li><li><span><a href="#Наиболее-проблемные-товары" data-toc-modified-id="Наиболее-проблемные-товары-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Наиболее проблемные товары</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Предложения-и-гипотезы-по-улучшению-опыта-пользователей:" data-toc-modified-id="Предложения-и-гипотезы-по-улучшению-опыта-пользователей:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предложения и гипотезы по улучшению опыта пользователей:</a></span></li></ul></div>

# %% [markdown]
# # Самокат. Мороженое

# %% [markdown]
# **Описание**
# Самокат позволяет пользователю поставить оценку и оставить отзыв на товар.
# Мы хотим использовать эти отзывы и оценки для улучшения наших товаров и процессов.
#
# **Дано**
# Выгрузка отзывов за последний месяц на мороженное "Самокат"
#     ``name_samokat`` - наименование товара
#     ``comment`` - отзыв на товар
#     ``rating`` - оценка заказа
#
# **Ожидаемый результат**
# Список гипотез "как можно улучшить опыт покупателей мороженного Самокат".
# Для гипотез, придумать как её можно проверить, описать каких дополнительных данных и исследований не хватает для её валидации?

# %% [markdown]
# ## Загрузка библиотек и предобработка данных

# %%
import spacy
import gensim
import nltk
from gensim.utils import simple_preprocess
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from collections import Counter
import pandas as pd

# %% [markdown]
# По ходу анализа было принято решение частицы "не" объединить со следующим словом

# %%
data = pd.read_excel("icecream_Samokat_1.xls")

# %%
data
# Out:
#                                            name_samokat  \
# 0     Мороженое Самокат вафельный стаканчик, пломбир...
# 1     Мороженое Самокат вафельный стаканчик, шоколад...
# 2     Мороженое Самокат пломбир классический, 15%, 2...
# 3     Мороженое Самокат с йогуртом, с клубникой, 10%...
# 4     Мороженое Самокат пломбир, шоколадный, 15%, в ...
# ...                                                 ...
# 3080  Мороженое Самокат вафельный стаканчик, пломбир...
# 3081  Мороженое Самокат эскимо, пломбир, с ванилью, ...
# 3082  Мороженое Самокат вафельный стаканчик, шоколад...
# 3083  Мороженое Самокат вафельный стаканчик, шоколад...
# 3084  Мороженое Самокат эскимо, двухслойный пломбир,...
#
#                                                 comment  rating
# 0                             Самое вкусное мороженое !       5
# 1                             Очень вкусное ! Настоящее       5
# 2                                  Вкуснейшее мороженое       5
# 3     Какая то гадость купил детям выкинули, прогорк...       1
# 4                                  Качественный продукт       4
# ...                                                 ...     ...
# 3080            Самое вкусное мороженое, как в детстве!       5
# 3081                            Очень вкусное мороженое       5
# 3082                           Очень вкусное мороженое!       4
# 3083                                Вкусное мороженое 👍       5
# 3084                                      Очень вкусное       5
#
# [3085 rows x 3 columns]

# %%
data.duplicated().sum()
# Out:
# 298

# %% [markdown]
# Удалять дубликаты некорректно, люди могли написать что-то одинаковое

# %%
data = data.query('rating < 4')
data = data.reset_index(drop=True)

# %% [markdown]
# Уберем положительные отзывы, т.к. для поставленной задачи они не слишком важны. В них, конечно, может содержаться полезная информация для улучшения сервиса, но в первую очередь необходимо отработать негативные моменты

# %% [markdown]
# ## Тематический анализ и частотный анализ слов

# %%
data['comment'] = data['comment'].str.replace('мороженое|мороженное', '')
# Out:
# C:\Users\stupa\AppData\Local\Temp\ipykernel_6336\2355543207.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['comment'] = data['comment'].str.replace('мороженое|мороженное', '')

# %% [markdown]
# Для более точного анализа слова уберем слово "мороженое", т.к. речь идет итак только о нем

# %%
reviews = data["comment"].tolist()

# %%
# Токенизация текста (разделение на отдельные слова)
def tokenize(text):
    return [token for token in simple_preprocess(text, deacc=True) if len(token) > 3]

# Создание словаря и корпуса
tokenized_reviews = [tokenize(review) for review in reviews]
dictionary = Dictionary(tokenized_reviews)
corpus = [dictionary.doc2bow(review) for review in tokenized_reviews]

# Обучение модели LDA
num_topics = 3  # Количество тем, которые хотим выделить
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)

# %%
# Собираем все слова из отзывов в один список
all_words = [word for review in tokenized_reviews for word in review]

# Определяем 10 наиболее часто встречающихся слов
word_freq = Counter(all_words)
print(word_freq.most_common(10))
# Out:
# [('вкус', 94), ('очень', 74), ('было', 56), ('привезли', 49), ('шоколад', 34), ('глазурь', 33), ('мороженое', 33), ('растаявшее', 27), ('невкусное', 27), ('невкусно', 24)]

# %%
# Определение самой популярной темы для каждого отзыва
most_popular_topic_per_review = [max(review, key=lambda x: x[1])[0] for review in lda_model[corpus]]

# %%
reviews_with_most_popular_topic_0 = [i for i, topic in enumerate(most_popular_topic_per_review) if topic == 0]

for i in reviews_with_most_popular_topic_0:
    print(data.loc[i]['comment'])
# Out:
# Какое то безвкусное
# Как будто порошок ела... Ну хотя бы холодным привезли😁
# Ничего особенного  вкуса ириски я так и непоняла
# Привезли упакованное откусанное
# непоняла прикола :(
# В глазури хрустит сахар. У мороженного странный привкус.
# Старая рецептура была вкуснее :(
# Структура непонятная
# Очень похоже на Коровку из Кореновки
# неожидала таким жирным))
# На любителей
# неочень понравилось, но для своих денег норм
# невкусно и дорого
# Слишком завышенный ценник
# На первый и после раз
# Вместо вкуса мороженого - вкус сливочного масла. Пойдёт на бутерброды
# В хвостике нет шоколадки :)
# Вкусненько вроде, но опять повторюсь. Структура непонятная. Хотелось бы побольше воды, но чтобы вкус был более насыщенным. Но чувствуется что натуральное, хорошенькое. И мята с малиной здорово.
# Ну ооооочень мало крошки((
# Гипер сладкое
# неочень, сильно чувствуется йогурт.
# Больше похоже на за пирожное,  чем на  (стих получился)
# Поддтаевшее и деформированное
# Полурастаеный был. Аромат манго кстати даже вкус, но хз. незашел
# рожок мягкий и нет шоколадки в низу рожка
# Как-то странно на желудке после него
# Вскрыта упаковка
# мало
# мало шоколадной крошки, очень мало
# Имеется горьковатый кислый привкус
# Слишком сладко, с манго лучше.
# несладкое, сильно горчит
# Пластилин вместо шоколада сверху, ничего хуже нет
# Горчит, сильно
# Как любитель пломбира могу сказать- невкусно
# Вкусно но привезли смятое
# Мало
# Потрясающий десерт, но уберите из него Сахар, он достаточно сладкий за счет состава фруктов зачем там Сахар непонятно
# Очень приторно
# Мороженное привезли растаявшее
# Вкус клубники нечувствуется
# Обычно норм, в этот раз незашло
# непонял ничего из вкуса....
# Вместо манго-маракуя отправили малина с мятой
# Приторно сладкое
# Отврптитьльное
# Почему-то горчит, по консистенции отличное!
# Безвкусное
# Вкусно но мало
# нето пальто, непломбир, мало жира
# Семена чиа немного бессмысленны: вкуса недают. А манговый - отличный
# Привезли растаявшее и смятое
# На вкус вкусно, но слегка горчит :(
# Дочь заболела
# Приторно сладкое
# Порой приходит без вкуса
# Привезли раз
# Шоколад как резина((
# неел
# непоняла консистенции, и не и нет лед, вкус как вкус
# Как сметаны замороженной поел
# Дорого
# Привезли сильно мятое
# Странный привкус
# Шоколад как пластилин отвратный
# Шоколад как пластилин отвратный
# Слишком приторно сладкое
# Ужасно. Назвать это мороженым - оскорбление для настоящего мороженого. У этого нечто отсутствует вкус клубники, отсутствует сливочность,  отсутствует сладость. В наличии только вкус и кислость как у кефира.
# Чувствуется, что невредно, но и её так вкусно
# Течет,упаковка треснута
# дорого и невкусно … прям совсем неклубничное. химоза
# А а
# Странная начинка 😐
# Привезли разваливающееся . Местами было не , а какой-то лед (
# Честно, много раз брала продукцию именно от Самокате. Взяв данный продукт, пожалела 1000 раз.На вкус кислый ( испорченный) Срок годности был нормальный. Впечатление испорчено. Впредь 1000 раз подумаю и перечитаю отзывы, чтобы заказать бренд Самоката...
# Мороженное имеет соленый вкус, что очень сильно чувствуется
# невкусное, плохая карамель , в начинке карамели нет вообще , описанию несоответствует, цега ему 20р
# Привезли растаявшее в обычном пакете с другими товарами, а как же термопакет…
# привезли нето
# Неоднозначно, слишком желейная оболочка, быстро тает
# Химический вкус
# отвратительный вкус
# Мороженное растаявшее, а потом опять за. Растекшееся по всей упаковке в замороженном виде.
# неочень понравилось. Шоколад на себя непохож
# Привезли расстаевшее
# Сухая мята очень сильно мешает.
# не, а мерзлая ледяная крошка
# Мороженое размораживалось и замораживалось повторно
# Очень маленькая пачка и странный привкус. Зато приятная текстура
# Несладкое
# Вафля мягкая совсем,  поломано 😔
# Горчит очень и дорого
# Горчит
#  было в поврежденной (вскрытой)  упаковке
# Мороженное по консистенции как песок, так бывает, когда сначала размораживают, потом замораживают опять, неочень приятно
# Мороженное в стаканчике должно быть с горкой, а недо краев. Отклонение от ГОСТ
# Привезли раз желе
# Растаянное
# Положили  раз до состояния сока ! Как это понимать ??? КТО ЭТО ДОЛЖЕН ЕСТЬ??? И почему я должен за это платить?!
# десерт пришел кислый
# Привезли раздавленное
# -
# Привезли подтаявшее
# Вкуснг, но дорого
# Привезли растаянное
# Привезли раз
# Немного несоответствует заявленному по ВКУСУ🫤
# В любом из такого мороженого, особенно в клубничном, остаётся ужасное послевкусие 🤢🤢🤢
# Дорого
# Слишком сладкое. невкусно
# Очень мало шоколадной крошки, как украли.
# Карамель отсутствует
# Первый продукт марки самокат, который мненепонравился, а пробовал я много чего. На вкус даже близко неклубничный йогурт
# немного горчит
# слишком сладкое
# Как будто испорчено
# Ваша работа ужасная, нельзя обманывать людей. Зачем вводите в заблуждение людей. Пишите, что заказ доставж
# Очень быстро тает, ощущение,  что везли со всеми остальными продуктами в сумке и оно успело разморозиться
# По сравнению с прошлым годом качество заметно упало
# Ужасное , от слово  неприсутствует совсем
# Очень сладкое
# Это непломбир, это обычное молочное . Нет кремообразной консистенции, присущей пломбиру
# Йогуртовый вкус горчит
# Отвратительный вкус, еще и испорченный
# Съедобно, но горчит
# Специфический вкус. На мой взгляд что-то нето) непоняла вкуса.
# неням-ням…
# В стаканчике другой вкус. В стаканчике пахнет молоком, а тут жиром.
# невкусный, привкус 100 раз замороженной воды. Дорого для такого вкуса
# недосталось
# Привкус странный
# Отвратительно и горько
# У ребенка вызвало аллергию
# Хочется сверху вместо желе сок)
# невкусно , как будто не а пластик
# Норм
# Товар был за 1 рубль, привезли крем брюле, а должен был быть пломбир.
# Сильно чувствуется вкус сах.зама, стаканчик горчит. Выбросила
# По акции взять можно,но пломбир настоящий должен быть пожирнее!
# Испортили качество,что то хрустит 😈 Сахар !!
# Привезли прокисшее
# Кудшая служба поддержки и клиентский сервис из всех что встречал
# Приятный аромат, но вкус неочень выразительный, на зубах помимо семечек малины как будто песок трескается
# Вечно приходит растаявшее или еще вдобавок прижатое наполнителем сверху
# Горчит
# Обосрался от этого мороженного сегодня с утра
# непрмвезли
# Вкус специфический, несладкий, в сравнении с классическим
# Мнекажется вы скоро начнёте продавать всё в спичечных коробочках…🤦‍♀️прошлым летом заказывала это  и оно было в три раза больше… мненежалко денег, но вы тогда в ладошке всё фотографируйте, чтобы люди понимали сколько это.
# Вафля очень мягкая
# Ожидала более насыщенного вкуса и нехватило сладости (точнее сладости совсем непочувствовала)
# Слишком мало
# Сверху какое то безвкусное жёлтое желе. В след раз невозьму
# Привезли расстаявшее
# Вологодское  лучше
# Чувствуется заменитель, ребёнок есть нестал
# Горчит
# Отсутствует!

# %%
reviews_with_most_popular_topic_1 = [i for i, topic in enumerate(most_popular_topic_per_review) if topic == 1]

for i in reviews_with_most_popular_topic_1:
    print(data.loc[i]['comment'])
# Out:
# Какая то гадость купил детям выкинули, прогорклый вкус, кароче несоветую
# Пластилиновый шоколад, который нетает во рту, пломбир без вкусный
# Слишком жирно
# Глазурь неожиданная на вкус и консистенцию, удивил состав глазури - хороший, вроде даже более полезный, чем обычная шоколадная глазурь, но непривычно
# Слишком жирное
# Это «» даже бомж есть небудет, нежели дети
# невкусно(
# Привезли растаявшее😒
# Привезли растаявшее
# Внутри вкусно. Но слой шоколада сверху как толстая плёнка, на вкус неочень
# Очень невкусный шоколад ( Прилепает к зубам…
# Вкус нормальный, но очень мало мороженного за такую цену
# То ли горчит, то ли что, непонятно, но вкус непонравился :(
# Состав
# Ванильное вкусное было, а это оказалось горьковатым.
# Мороженное, к сожалению очень часто привозят уже растаявшее.
# Что-то изменилось или заменилось в составе, стало как протеиновое, а до было всегда вкусное сливочное, сейчас как сухое молоко или что-то подобное
# Невкусно
# И коробка уменьшилась и вкус ужасный
# Мороженое непонравилось.
# на вкус больше льда, чем мороженого, недостаточно насыщенное
# Здравствуйте. Примите пожалуйста меры по целостности содержимого продукта в пачке. Мороженное очень вкусное НО! Зачастую при распаковке пломбир оказывается нена палочке а внутри самой пачки.
# Очень ненасыщенн вкус(
# Шоколад немного резиновый, в остальном всё супер
# невкусно
# Мнепоказалось через чур приторным
# Интересно- состоит из двух частей. Плохо- части одинаково сладкие и совсем неразличаются по вкусу, причем бисквита чересчур много
# Совсем невозможно есть, вкус заменителя сахара вяжет во рту
# Очень приторный вкус,ужасно просто
# Гадкая горькая глазурь
# Растаеное,непонравилось
# Привезли полностью растаявшим((
# невкусный шоколад сверху
# Ужасное  что раз, все сломано и по вкусу вода водо
# Верните все как было, это невкусно
# Наверное неплохое. Но доехало почти полностью расстаявшим. Пить нестал.
# На удивление невкусное сочетание оказалось 🥴
# Глазурь как пластилин, пломбир водянистый как за молоко неболее того.
# непонравилось
# Шоколад плохой
# недовезли
# Привезли полностью растаявшее
# По вкусу  молоко
# за такую цену очень мало(
# Привезли нетот вкус
# Мороженое вкусное, а стаканчик совсем картонный
# Вкус хороший, мало калорий, очень понравилось, однако плохое наполнение и  неплотное и много пустот в стаканчике
# Горькое 🤢
# Очень невкусный шоколад
# Думала будет больше :(очень вкусный
# невкусный ,напоминает лёд
# Деформированное, постоянно растаялое
# Мороженное непонравилось, чувствуется вкус горечи !
# Привезли размороженный плоский рожок. Такое впечатление, что его просто сплюснули, вафля нехрустящая, а мокрая.
# Очень странный вкус. Возможно слишком жирное
# неположили в заказ
# Крошки неравномерные и их меньше чем в подобных мороженых
# Шоколад просто ужас, сплошное пальмовое масло, а пломбир как разбавленная вода с сухим молоком. Невкусно.
# Самое ужасное , никогда небуду его советовать никому🤢
# Упаковка неудобная
# В мороженом ощущается порошок, к сожалению оно неочень приятное на вкус
# С доставкой недоезжает
# Шоколад как пластилин, во рту вообще нетает
# Мненезашло. Люблю когда  тает во рту, а глазурь плавится. Желе совсем неплавится и начинает таять только отдельно от мороженного. При этом желе, когда холодное вообще без вкуса-запаха и только растаяв появляется слабый вкус.
# Невкусный пломбир. Глазурь неимеет вкуса, шоколад нехрустит.
# Его изменили и  вКус стал очень горьким(
# Безвкусный
# Мороженое дорогое и ждёшь от него высокого качества, но в последний раз у его вафли были твердые камочки, причём у обоих мороженых, раньше такого небыло именно у этого заказа
# Вафельный рожок отсыревший
# Привезли расплющенное , причем обе штуки(
# Без вау эффекта, хочется, чтобы оно было менее химозным, и в нем было больше кусочков клубники
# Молочное , несливочный пломбир.
# Ужасный вкус, нет ни намека несладость
# Самое плохое  на свете из всех, что я пробовал. А я, поверьте, попробовал кучу мороженного в России. Это  мало того, что со вкусом некачественного пластика, так еще и кислое, отвратительное. Вкус далёк от обычного нормального мороженного
# невкусно, после вкусил отвратительное
# Приехало растаявшее
# Глазурь похожа на пластилин,непонравилось
# Самое мерзкое
# Ну оочень сладкий
# Привезли растаявшее  и сломанное под тяжестью других продуктов(((
# Полностью растаявшее, вафельный стаканчик весь размок
# Мороженое превратилось в жижу
# Глазурь из маргарина
# Неудобная упаковка
# привезли полностью растаявшее
# Всегда брала это , а в последний раз разочаровалась. Очень ощущаются какие-то крупинки. Или переморожено было. В общем, что-то с технологией производства. неприятное ощущение. Надеюсь, исправят
# Ужасное
# Кислое
# Привезли абсолютно растаявшее
# недоставили, а деньги сняли за .
# Растаявшее

# %%
reviews_with_most_popular_topic_2 = [i for i, topic in enumerate(most_popular_topic_per_review) if topic == 2]

for i in reviews_with_most_popular_topic_2:
    print(data.loc[i]['comment'])
# Out:
# На любителя
# Растаяло
# Раньше было вкуснее :( сейчас слишком горькое
# Раньше было вкуснее
# Дорогое
# 2 мороженого были заново переморожены, лёд внутри и подтеки
# Очень невкусная и странная «шоколадная глазурь»
# Кислое, невкусное, как будто заморрзили невкусный несладкий йогурт, непонравилось никому из семьи, даже ребенку. Раньше было вкусное клубничное тоже типа с йогуртом, это совсем на него непохоже
# Привезли помятое. Такое ощущение , что растаяло, потом опять замёрзло. Ну и, соответственно лёд на зубах хрустит. Неприятно
# Нет выраженного вкуса Брюле.
# Слишком много сахара для пломбира
# Странное послевкусие, непохоже на пломбир
# Сильно подтаявшее
# Мыльное послевкусие
# Средне
# невкусная глазурь сверху мороженного. Она неотламывается при откусывании (как у др.производителец мороженого), а прилипает к зубам как пластилин.
# на любителя. как замороженный лед фруктовый
# невкусная глазурь(
# Такое редкостное Г!!!
# невкусная глазурь, мягкая
# Вообще невкусное, как сметана или сливки, несладкое, съела пару ложек и выбросила.
# Привела просто жидкость в пакете, настолько все растаяло, даже открыть невозможно
# Обычно  хорошее, в последний раз просто ужастнон
# Видимо таяло  , мятое, всё в инее
# Курьер приносит его сплющенным
# Глазурь неочень вкусная, немного резиновая(
# Было все смятое, раз и после снова за.
# непонравилось , невкусное (((у вас было в форме трубочки с шоколадным центром , вот оно идеальное и эскимо ваши как из детства
# невкусное
# невкусная глазурь
# невкусное (((
# невкусное
# Глазурь невкусная
# Пришло все растаевшее, просто в пакете валялось, как хлеб, без специальной сумки
# Овно с молоками в глазури
# в десерте очень много косточек
# Ну такое
# Мороженное непохоже на пломбир, скорее молочное
# Вафля как сухарь, вдобавок и невкусная
# неочень вкусное , есть аналоги гораздо вкуснее
# Ожидала друго вкуса. Но глазурь нешоколадная, она даже нетает во рту,неломается как шоколад,само  указано как пломбир ,но вкус водянистый ненасыщенно сливочный.
# На любителя неоправдало моих надежд так и непонятно с чем данное  пока непрочитаеш
# Безвкусная субстанция в замороженном виде
# Странная глазурь. Как будто резиновая.
# Много льда, всё помятое, очень сладко
# Мороженное было слишком мягкое, как будто в тепле несли
# Рожок мягкий и нехрустящий. Как будто было разморожено и снова заморожено
# Вкус граната слабый, оставляет послевкусие дешевого вина… вишня - неощущается совсем ((
# невкусная шоколадная глазурь
# На любителя
# Очень сильный привкус сахзама,  без сахара которое в Краснодаре продается(тоже самокат) в разы вкуснее и менее калорийно
# Вкус так себе
# Все помятое было
# На любителя
# На любителя, понравилось только одному из всей семьи
# Пришло с крыжкой внутрь,открытое
# Храните  в нормальных морозильных камерах и привозите в специальных пакетах. Иногда курьеры привозят в обычном пакете с остальными продуктами.
# Пришло скисшее. Горьчит
# В целом хороший, но больно много косточек
# Пальма в составе
# Постоянно приезжает растаявшим
# Ужасно невкусное  на сухом молоке, сразу непрочитала.
# Потаяло
# То, , что было год назад было на порядок вкуснее
# Мороженое было растаявший. Видно было, что уже нераз таяло и его замораживали снова.
# Мороженое было растаявший. Видно было, что уже нераз таяло и его замораживали снова.
# Такое себе, цвет шоколадный, а вкус нет
# Средне
# Так себе
# Как будто ешь масло шоколадное
# Мороженое неправильно хранилось, было переморожено
# Ужасное состояние, как будто помяли несколько раз
# Мороженое растаяло, оказалась жижа в пакете
# Оказался слишком сливочным, жирноватым:( Такая оценка - дело вкуса
# Растаяло и снова заморозили
# Мерзкий привкус горечи
# В мороженом был волос чёрный, пришлось выкинуть. Желание заказывать пропало.
# Химозный запах, для мен очень сладко
# Кисловато
# Раньше  было в другой упаковке, гораздо вкуснее, чем это. Без сахара, без вкуса
# Курьер доставлял заказ час и  полностью растаяло
# Слабенько, глазурь и пломбир существуют отдельно друг от друга
# Вкус неплохой, но смущает структура пломбира. В нем как будто попадается мука или нерастворенные частицы сахара
# Было бы круто если это было без сахара
# Растаяло)
# Мороженое вкусное, но дорогое для такого маленького количества
# Тот вариант этого клубничного мороженого, который продавался прошлым летом, был гораздо вкуснее!
# Сильный привкус подсластителя
# На любителя ..
# Приехало пере
# Доставили мятым
# Растаяло
# Мороженое пришло очень мятое, очевидно его несколько раз размораживали и замораживали.Расстроилась (
# Раньше это  было без огромного количества мякоти, а сейчас мазня с пюре клубники (люблю  без кусочков и мякоти, и очень разочаровалась)
# Мороженое горчит, пришлось выкинуть
# Талое приехало
# Дерьмо
# Раньше был вкуснее
# шоколадная глазурь, которой покрыто , по текстуре и вкусу как сладкий пластилин
# Пальмовое масло в составе глазури.
# Привезли кашу вместо мороженого. Между бутылок все смялось и растаяло за 2 часа доставки
# Было переморожено , с ледяной крошкой , что говорит о нарушении хранения
# Пришло кашей , вкус неоценили
# Показалась сильно сладкой
# несамое вкусное
# Странный горький привкус (возможно,  из-за сахзама, но есть прямо невозможно было, выкинула)
# Само  показалось водянистым и ненасыщенным, глазурь тоже
# Раньше часто покупала это , и купила в очередной раз. На вкус как замороженный лёд с ванилью.
# Было уже залежавшееся
# Химия
# Сильно сладко
# На мой вкус слишком сладко
# невкусное, как будто на растительном жире , послевкусие
# Неприятный химозный привкус
# непохоже на крембрюле
# Было разбито
# Слишком много ароматизатора
# Было переморожено все во льду
# Слишком сладко
# Глазурь как пластилин с крупицами сахара
# На любителя
# К сожалению пришло в виде лепешки, непо винекурьера, так как лепешка была замороженная, то есть это с мороженым произошло раньше
# Было подтаявшим
# Растаяло, мокрая вафля
# Шоколадная глазурь ужасная, дешевка. Само  нормальное
# мы такое неели
# Водянисто-сливочное  вперемешку с крошками брауни
# Растаяло
# привезли сплюснутым, ну ладно
# Было сильно вкуснее
# Ужасно невкусное 👎
# Принесли без сумки холодильника, растаяло
# Мороженное растаяло и потеряло свою форму. неимело презентабельный вид.
# Оно было растаявшее и переза
# Привозят постоянно помытый пломбир на половину заполненый стаканчик
# Будто за варенье, сильно заморожено, прилипает к губам

# %%
# Получение списка тем и наиболее вероятных слов для каждой темы
topics_words = lda_model.show_topics(num_topics=num_topics, num_words=10)

# Вывод наиболее популярных слов для каждой темы
for topic_id, words in topics_words:
    print(f"Тема {topic_id}: {words}")
# Out:
# Тема 0: 0.019*"привезли" + 0.019*"вкус" + 0.013*"горчит" + 0.009*"очень" + 0.008*"мало" + 0.007*"сильно" + 0.007*"вкуса" + 0.007*"сладкое" + 0.007*"слишком" + 0.006*"чувствуется"
# Тема 1: 0.032*"вкус" + 0.027*"очень" + 0.015*"шоколад" + 0.013*"привезли" + 0.010*"невкусно" + 0.010*"вкусное" + 0.010*"растаявшее" + 0.009*"мороженое" + 0.009*"невкусныи" + 0.008*"глазурь"
# Тема 2: 0.036*"было" + 0.014*"растаяло" + 0.012*"глазурь" + 0.011*"невкусное" + 0.011*"мороженое" + 0.010*"вкуснее" + 0.008*"очень" + 0.008*"будто" + 0.008*"раньше" + 0.008*"невкусная"

# %% [markdown]
# Исходя из визуального анализа каждой темы и частотного анализа слов для каждой из них можно выделить 3 основных проблемных темы:
# Проблемы со вкусом, проблемы с доставкой, и "раньше было лучше"

# %%
# последовательность и наполнение этих тем меняются при каждом перезапуске, но это не мешает составить именно такой выбор тем

# %% [markdown]
# Посмотрим на проблемы в определенных темах

# %%
topics_keywords = {
    "taste": ['горьк', 'горч', 'сладк', 'невкус', 'шокол', 'глазу', 'ненатурал', 'ужас'],
    "delivery": ['таявш', 'раста',  'курьер', 'упаков', 'привез'],
    "nostalgia": ['раньш', 'было', 'лучше', 'вкуснее', 'партия']
}

for topic, keywords in topics_keywords.items():
    print(f"Тема: {topic}")
    total_count = 0
    for keyword in keywords:
        count = data["comment"].str.contains(keyword, case=False).sum()
        total_count += count
        print(f"{keyword}: {count}")
    print(f"Итог: {total_count}\n")
# Out:
# Тема: taste
# горьк: 24
# горч: 19
# сладк: 27
# невкус: 77
# шокол: 61
# глазу: 35
# ненатурал: 3
# ужас: 33
# Итог: 279
#
# Тема: delivery
# таявш: 52
# раста: 78
# курьер: 6
# упаков: 17
# привез: 50
# Итог: 203
#
# Тема: nostalgia
# раньш: 15
# было: 52
# лучше: 7
# вкуснее: 15
# партия: 1
# Итог: 90

# %% [markdown]
# ## Наиболее проблемные товары

# %%
data.groupby('name_samokat', as_index = False).agg({'rating':['mean', 'count']}).sort_values(by=('rating', 'mean'))
# Out:
#                                          name_samokat    rating
#                                                            mean count
# 9   Мороженое Самокат вафельный стаканчик, пломбир...  1.714286    42
# 22  Мороженое Самокат эскимо, пломбир, с ароматом ...  1.750000     4
# 17  Мороженое Самокат с йогуртом, с клубникой, 10%...  1.800000   100
# 14              Мороженое Самокат пломбир, 15%, 270 г  1.800000    10
# 8   Мороженое Самокат в вафельном стаканчике, плом...  1.810811    37
# 16  Мороженое Самокат пломбир, шоколадный, 15%, в ...  1.812500    16
# 18  Мороженое Самокат стаканчик, сливочное, со вку...  1.875000     8
# 12  Мороженое Самокат пломбир классический, 15%, 2...  1.882353    17
# 21  Мороженое Самокат эскимо, пломбир с ароматом в...  1.895522    67
# 7   Мороженое Самокат в вафельном стаканчике, вани...  1.896552    29
# 10  Мороженое Самокат вафельный стаканчик, пломбир...  1.961538    26
# 6   Мороженое Самокат в вафельном рожке, пломбир в...  2.000000     2
# 20  Мороженое Самокат эскимо, двухслойный пломбир,...  2.097561    41
# 23  Мороженое Самокат эскимо, пломбир, с ванилью, ...  2.103448    29
# 5   Мороженое Самокат в вафельном рожке, двухслойн...  2.162162    37
# 13   Мороженое Самокат пломбир шоколадный, 13%, 270 г  2.200000     5
# 19  Мороженое Самокат эскимо, Бостон-Брауни класси...  2.200000    20
# 3   Десерт растительный Самокат маракуйя с манго и...  2.218750    32
# 11  Мороженое Самокат вафельный стаканчик, шоколад...  2.222222    27
# 1   Десерт растительный Самокат гранат и вишня, за...  2.222222    18
# 15  Мороженое Самокат пломбир, с шоколадной крошко...  2.285714    21
# 4   Мороженое Самокат Трубочка, двухслойное, в гла...  2.319149    47
# 2   Десерт растительный Самокат малина с зеленью м...  2.500000    18
# 0   Десерт растительный Самокат банан и клубника, ...  2.500000     4

# %% [markdown]
# ## Вывод

# %% [markdown]
# 1. Наибольшее недовольство пользователей вызывают вкусовые характеристики товара. Невкусные шоколад/глазурь, горько, сладко и т.д.
# 2. Следующее недовольство вызвано доставкой. Привезли растаявшим или были проблемы с упаковкой
# 3. Еще одна причина недовольства "раньше было лучше". Это может быть вызвано субъективным восприятием клиентов или же изменением технологий производства

# %% [markdown]
# ## Предложения и гипотезы по улучшению опыта пользователей:

# %% [markdown]
# 1. По вкусовым характеристикам: выбрать наиболее проблемные товары (в совокупности по количеству заказов и средней оценке), детально изучить отзывы, попробовать изменить технологию производства и вкус товара, испытать его на различных дегустационных группах. После достижения устраиваемого результата возобновить поставки и следить за динамикой оценок и отзывами о вкусе
# 2. По проблемам с доставкой: установить регламенты для курьеров и ПВЗ (не собирать мороженое в заказ до прибытия курьера, хранить в термосумке и тд); установить время доставки с мороженым, чтобы оно не успело растаять; для отслеживания изменений необходимо привязать к данным время доставки и время сборки заказа, смотреть за корелляцией отзывов и временем.
# 3. Решение проблемы "раньше было лучше" аналогичное первой проблемы. Но от ностальгических чувств никогда не получится избавить польностью, это слишком субъективно :)
