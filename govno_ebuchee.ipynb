# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Влад :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Анализ продаж компьютерных игр интернет-магазина "Стримчик".

# %% [markdown]
# Из открытых источников нам доступны исторические данные о продажах игр, интернет-магазина «Стримчик», который продаёт по всему миру компьютерные игры, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# Цель исследования:
#
# Составить портрет пользователя каждого региона и проверить несколько гипотез, а именно:
#
# 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# 2. Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Ход исследования:
#
# Данные я получу из файла:
#
# /datasets/games.csv
#
# Таким образом, мое исследование пройдет в шесть этапов:
#
# 1. Изучение данных
# 2. Предобработка данных
# 3. Исследовательский анализ данных
# 4. Составление портрета пользователя каждого региона.
# 5. Проверка гипотез
# 6. Написание общего вывода

# %% [markdown]
# # Описание данных
#
# Name — название игры
#
# Platform — платформа
#
# Year_of_Release — год выпуска
#
# Genre — жанр игры
#
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
#
# EU_sales — продажи в Европе (миллионы проданных копий)
#
# JP_sales — продажи в Японии (миллионы проданных копий)
#
# Other_sales — продажи в других странах (миллионы проданных копий)
#
# Critic_Score — оценка критиков (максимум 100)
#
# User_Score — оценка пользователей (максимум 10)
#
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных
# игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %%
# Импортируем библиотеки 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# считаем данные из csv-файла 
try: games = pd.read_csv("/datasets/games.csv")
except: games = pd.read_csv("games.csv")

# %%
games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Сразу бросается в глаза большое количество пропусков, к которым вернемся чуть позже.

# %%
# посмотрим информацию о датафрейме
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Смена типа данных требуется в столбце "User_Score", с остальными типами данных все в порядке.

# %%
games.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# Практически все пропуски приходятся на 3 последних столбца: Critic_Score, User_Score, Rating.
# Все 3 столбца являются оценкой игр со стороны профессионала\любителя, поэтому можно предположить, что во времена расцвета этих игр не была развита практика оценки и на основе этого ориентации на отзывы и рейтинги.
#
# Нет возможности заполнить пропуски медианными или средними значениями даже по каждому жанру, поэтому заполним значением "-1", чтобы не смешивать значения с реальными оценками жанров, которые могут равняться в том числе и 0,00.
#
# Также есть пропуски в столбцах Name, Genre и ровно так же, как с остальными столбцами, невозможно заполнить их чем-то средним на основе имеющихся данных, поэтому оставим их в прежнем виде, так как количество пропусков не является статистически значимым.
#
# В столбце Year_of_Release попробуем оттолкнуться от имеющейся информации по году выпуска игры на других платформах.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(games)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Несколько предположений есть. Название графика и осей, также можно добавить описательную характеристику как среднее значение количества пропусков в столбце.

# %%
# посмотрим количество явных дубликатов
games.duplicated().sum()
# Out:
# 0

# %%
# приведем к нижнему регистру названия столбцов
games.columns = games.columns.str.lower()
games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
games['platform'] = games['platform'].str.lower()

# %%
games['name'] = games['name'].str.lower()

# %%
# изменим тип данных в столбце year_of_release 
games['year_of_release'] = games['year_of_release'].astype('Int64')

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# Моя строчка, удали коммент и две нижних ячейки потом
games.drop_duplicates(subset=['name', 'platform', 'year_of_release'], inplace=True)

# %%
# duplicateRows = games[games.duplicated(['name', 'platform', 'year_of_release'])]
# duplicateRows

# %%
# games = games.drop(labels = [14244, 16230],axis = 0)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %%
games
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         wii sports      wii             2006        Sports
# 1                  super mario bros.      nes             1985      Platform
# 2                     mario kart wii      wii             2008        Racing
# 3                  wii sports resort      wii             2009        Sports
# 4           pokemon red/pokemon blue       gb             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  samurai warriors: sanada maru      ps3             2016        Action
# 16711               lma manager 2007     x360             2006        Sports
# 16712        haitaka no psychedelica      psv             2016     Adventure
# 16713               spirits & spells      gba             2003      Platform
# 16714            winning post 8 2016      psv             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил.

# %% [markdown]
# ### Промежуточные итоги
# Изучили информацию о датасете. Выяснили, что в нем отсутствуют дубликаты, наметили столбцы, в которых требуется замена пропусков, также один столбец требует замены типа данных.
# Можем приступать к предобработке данных.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %% [markdown]
# ## Подготовка данных

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# В даннном случае tbd означает "неизвестное значение", по сути аналог NaN, поэтому можно заменить tbd на NaN и привести столбец к формату float.

# %%
games['user_score'] = games['user_score'].replace('tbd', np.NaN)
games['user_score'] = games['user_score'].astype('float')
games['user_score'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
# обработаем пропуски в столбце critic_score
games['critic_score'] = games['critic_score'].fillna(-1)

# %%
# обработаем пропуски в столбце user_score
games['user_score'] = games['user_score'].fillna(-1)

# %%
games['critic_score'].isnull().sum()
# Out:
# 0

# %%
games['user_score'].isnull().sum()
# Out:
# 0

# %%
# обработаем пропуски в столбце rating
games['rating'] = games['rating'].fillna(-1)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Хорошее решение для столбца, который содержит категориальные данные, поможет определить ключевое различие в потрете пользователя
#
#         games['rating'] = games['rating'].fillna(-1)
#
# оптимальнее вариант
#
#         .fillna('unknown')
#
# Можно посмотреть на частотность использования категорий рейтинга, по отношению к остальным
#
#         EC         8
#         K-A        3
#         RP         1
#         AO         1

# %%
games.isna().sum()
# Out:
# name                 1
# platform             0
# year_of_release    269
# genre                1
# na_sales             0
# eu_sales             0
# jp_sales             0
# other_sales          0
# critic_score         0
# user_score           0
# rating               0
# dtype: int64

# %%
games["year_of_release"].describe()
# Out:
# count    16444.000000
# mean      2006.485101
# std          5.876309
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: year_of_release, dtype: float64

# %% [markdown]
# Мы можем увидеть, что год выпуска находится между 1980 и 2016. Но заменять средним или медианным значением мы не можем, так как это отразится на достоверности дальнейшего анализа. Оставим как есть.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />проверим корректность алгоритма заполнения пропусков

# %%
# check
# жизненный срок платформы

years_of_life = games.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)
# Out:
#            min   max  years_of_life
# platform
# 2600      1980  1989              9
# 3do       1994  1995              1
# 3ds       2011  2016              5
# dc        1998  2008             10
# ds        1985  2013             28
# gb        1988  2001             13
# gba       2000  2007              7
# gc        2001  2007              6
# gen       1990  1994              4
# gg        1992  1992              0
# n64       1996  2002              6
# nes       1983  1994             11
# ng        1993  1996              3
# pc        1985  2016             31
# pcfx      1996  1996              0
# ps        1994  2003              9
# ps2       2000  2011             11
# ps3       2006  2016             10
# ps4       2013  2016              3
# psp       2004  2015             11
# psv       2011  2016              5
# sat       1994  1999              5
# scd       1993  1994              1
# snes      1990  1999              9
# tg16      1995  1995              0
# ...

# %%
# check
# жизненный срок платформы

years_of_life = games.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)
# Out:
#            min   max  years_of_life
# platform
# 2600      1980  1989              9
# 3do       1994  1995              1
# 3ds       2011  2016              5
# dc        1998  2008             10
# ds        1985  2013             28
# gb        1988  2001             13
# gba       2000  2007              7
# gc        2001  2007              6
# gen       1990  1994              4
# gg        1992  1992              0
# n64       1996  2002              6
# nes       1983  1994             11
# ng        1993  1996              3
# pc        1985  2016             31
# pcfx      1996  1996              0
# ps        1994  2003              9
# ps2       2000  2011             11
# ps3       2006  2016             10
# ps4       2013  2016              3
# psp       2004  2015             11
# psv       2011  2016              5
# sat       1994  1999              5
# scd       1993  1994              1
# snes      1990  1999              9
# tg16      1995  1995              0
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы внесли искажения в колонку год выпуска игры, которые приводят к ошибкам при определении срока жизни платформ
#
# Стоит посмотреть на платформы, к которым относятся пропуски, __и с легкостью расстанешься с ними ...__
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Да, понял ошибку, решил оставить данные в изначальном виде.

# %%
# посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# ### Промежуточные итоги
# Обработали пропуски в тех столбцах, где это можно было сделать, имея достаточное количество данных и не повредив дальнейшему анализу. Привели названия столбцов к нижнему регистру и посчитали суммарные продажи во всех регионах, записав их в отдельный столбец.
# Ошибки в данных устранили и можем приступать к исследовательскому анализу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Посмотрим, сколько игр выпускалось в разные годы

# %%
game_each_year = games.pivot_table(index='year_of_release', values='name', aggfunc='count')

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=game_each_year)
plt.title('Количество игр')
plt.xlabel('Год')
plt.ylabel('Количество выпущенных игр')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец
#
#         можно убрать легенду

# %% [markdown]
# До 1995 года игры практически не выпускались. Далее с развитием прогресса и освоением новых технологий ежегодный рост выпуска игр невозможно не заметить, отметим резкий скачок в 2002-2003 годах и абсолютный пик в 2009, после чего график идет на спад. Это можно объяснить развитием других технологий, в том числе мобильных, которые заставляют потребителей переходить на новые платформы, также играет роль обычный интерес к чему-то новому.

# %% [markdown]
# ### Как менялись продажи по платформам

# %%
sales_on_platform = games.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False)

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=sales_on_platform.index,y=sales_on_platform['total_sales'])
plt.title('Продажи по платформам за весь период')
plt.xlabel('Платформа')
plt.ylabel('Количество продаж')
plt.show()

# %% [markdown]
# На графике видно, что вне конкуренции консоль PS2, далее по убыванию идут X360, PS3, Wii, DS и PS, после чего глобальное провисание почти в 3 раза до следующей платформы.

# %%
top_platform_games = games.query('platform == ["ps2","x360","ps3","wii","ds","ps"]')

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# вот выброс о котором тебе говорят брат, одна игра 1985 года есть, что пиздеж какой-то, это надо удалить
# а теперь ниже увидел, что тип это убрал. только фишка в том, что ты убрал в свой пивот таблице, а в общей это осталось.
# соотвтетсвенно ниже сделана бесполезная хуйня, ты в сводной таблице заменил значение на НаН и все
games.query('platform == "ds"')['year_of_release'].value_counts()
# Out:
# 2008    492
# 2009    403
# 2007    376
# 2010    323
# 2006    201
# 2011    153
# 2005    118
# 2004     23
# 2012     23
# 2013      8
# 1985      1
# Name: year_of_release, dtype: Int64

# %%
top_platforms_by_years = top_platform_games.pivot_table(
                                 index = ['year_of_release'], 
                                 columns = ['platform'],
                                 values = ['total_sales'],
                                 aggfunc =  ['sum'])
top_platforms_by_years.plot(figsize = (15,8))
plt.title('Сменяемость платформ для игр')
plt.xlabel('Год')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# Исходя из графиков, можно сделать вывод, что характерный срок жизни одной платформы около 10 лет (PS - 1994-2003, PS2 - 2000-2011, Wii - 2006-2016 и так далее).
# Все лидирующие платформы теряют динамику продаж и к 2016 году остаются по сути только в памяти большинства пользователей, уступая место более современным консолям.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Платформа DS выпущена 21 ноября 2004 года, значение выброса в нашей таблице уникально, заменим его на Nan.

# %%
top_platforms_by_years
# Out:
#                         sum
#                 total_sales
# platform                 ds      ps     ps2     ps3     wii    x360
# year_of_release
# 1985                   0.02     NaN     NaN     NaN     NaN     NaN
# 1994                    NaN    6.03     NaN     NaN     NaN     NaN
# 1995                    NaN   35.96     NaN     NaN     NaN     NaN
# 1996                    NaN   94.70     NaN     NaN     NaN     NaN
# 1997                    NaN  136.17     NaN     NaN     NaN     NaN
# 1998                    NaN  169.49     NaN     NaN     NaN     NaN
# 1999                    NaN  144.53     NaN     NaN     NaN     NaN
# 2000                    NaN   96.37   39.17     NaN     NaN     NaN
# 2001                    NaN   35.59  166.43     NaN     NaN     NaN
# 2002                    NaN    6.67  205.38     NaN     NaN     NaN
# 2003                    NaN    2.07  184.31     NaN     NaN     NaN
# 2004                  17.27     NaN  211.81     NaN     NaN     NaN
# ...

# %%
top_platforms_by_years = top_platforms_by_years.replace(0.02, np.NaN)

# %%
top_platforms_by_years
# Out:
#                         sum
#                 total_sales
# platform                 ds      ps     ps2     ps3     wii    x360
# year_of_release
# 1985                    NaN     NaN     NaN     NaN     NaN     NaN
# 1994                    NaN    6.03     NaN     NaN     NaN     NaN
# 1995                    NaN   35.96     NaN     NaN     NaN     NaN
# 1996                    NaN   94.70     NaN     NaN     NaN     NaN
# 1997                    NaN  136.17     NaN     NaN     NaN     NaN
# 1998                    NaN  169.49     NaN     NaN     NaN     NaN
# 1999                    NaN  144.53     NaN     NaN     NaN     NaN
# 2000                    NaN   96.37   39.17     NaN     NaN     NaN
# 2001                    NaN   35.59  166.43     NaN     NaN     NaN
# 2002                    NaN    6.67  205.38     NaN     NaN     NaN
# 2003                    NaN    2.07  184.31     NaN     NaN     NaN
# 2004                  17.27     NaN  211.81     NaN     NaN     NaN
# ...

# %% [markdown]
# ### Определим актуальный период

# %% [markdown]
# Нужно определить актуальный период имеющихся данных для прогноза на следующие периоды. На мой взгляд, актуальными могут быть данные, начиная с 2011 года, так как это годы сразу после пика, в это время были представлены почти все самые популярные консоли за все время, многие из них не успели уйти с витрин магазинов, а также 5 лет - оптимальный срок для динамично меняющейся индустрии.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#         actual_games = games.query('year_of_release >= 2005')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поменял.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат
#     и тут кста пизда важно на мой взгляд брат, от этого в дальнейшем исследовании многое зависит</b></font>

# %%
# а чем обосновано то, что ты актуальный период выбрал 2011 год? 
# я в своем проекте выбирал 2013, когда появились платформы нового поколения пс4 и хбох оне
# советую сделать либо так либо со своим обоснованием
actual_games = games.query('year_of_release >= 2011')
actual_games
# Out:
#                                  name platform  year_of_release         genre  \
# 16                 grand theft auto v      ps3             2013        Action
# 23                 grand theft auto v     x360             2013        Action
# 29     call of duty: modern warfare 3     x360             2011       Shooter
# 31          call of duty: black ops 3      ps4             2015       Shooter
# 33                pokemon x/pokemon y      3ds             2013  Role-Playing
# ...                               ...      ...              ...           ...
# 16703                strawberry nauts      psv             2016     Adventure
# 16707                aiyoku no eustia      psv             2014          Misc
# 16710   samurai warriors: sanada maru      ps3             2016        Action
# 16712         haitaka no psychedelica      psv             2016     Adventure
# 16714             winning post 8 2016      psv             2016    Simulation
#
# ...

# %% [markdown]
# ### Продажи по актуальным данным

# %%
# выведем актуальные платформы с 2011 года
actual_games['platform'].unique()
# Out:
# array(['ps3', 'x360', 'ps4', '3ds', 'wii', 'ds', 'xone', 'wiiu', 'pc',
#        'psv', 'psp', 'ps2'], dtype=object)

# %%
# выведем продажи для этих платформ
sales_by_actual_platforms =actual_games.pivot_table(
                                 index = ['platform'], 
                                 values = ['total_sales'],
                                 aggfunc =  ['sum'])
sales_by_actual_platforms.sort_values(('sum', 'total_sales'),ascending = False)
# Out:
#                  sum
#          total_sales
# platform
# ps3           445.56
# x360          380.38
# ps4           314.14
# 3ds           257.81
# xone          159.32
# pc             97.68
# wii            95.02
# wiiu           82.19
# psv            53.81
# ds             38.73
# psp            29.01
# ps2             0.45

# %% [markdown]
# В топ-5, начиная с 2011 года, входят X360, PS3, PS4, 3DS и XOne.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# выведем график продаж этих платформ с 2011 года
top_platforms_actual_games = actual_games.pivot_table(
                                 index = ['year_of_release'], 
                                 columns = ['platform'],
                                 values = ['total_sales'],
                                 aggfunc =  ['sum'])
top_platforms_actual_games.plot(figsize = (20,10))
plt.title('Продажи по платформам с 2011 года')
plt.xlabel('Год')
plt.ylabel('Количество продаж')

# сделаем легенду покрасивее, удали комменты и посмотри разницу
# ax = plt.gca()
# legend_labels = [f"{col[2]}" for col in top_platforms_actual_games.columns]
# ax.legend(legend_labels, loc='upper right')

plt.show()

# %% [markdown]
# Практически все платформы потеряли свою актуальность, перспективу можно увидеть у PS4 и XOne.

# %% [markdown]
# ### График «ящик с усами» по глобальным продажам игр в разбивке по платформам

# %%
# построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам
actual_games.boxplot(column = ['total_sales'],by = ['platform'],figsize=(16, 10))
plt.ylim([0, 2])
plt.title('Глобальные продажи')
plt.xlabel('Платформа')
plt.show()

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам для нижней части boxplot-ов
actual_games.boxplot(column = ['total_sales'],by = ['platform'],figsize=(16, 10))
plt.ylim([0, 1])
plt.title('Глобальные продажи')
plt.xlabel('Платформа')

plt.yticks([i * 0.1 for i in range(11)])  

plt.show()

# здесь я советовал бы сделать лимит до единицы и добавить больше отсечек на осе y. можешь сам настроить как нравится в yticks

# %% [markdown]
# Выделяются в отрицательном контексте медианы PSP, PSV и PS2, в положительном - X360, PS3, XOne и PS4. Выше располагаются 75% квартили PS3, PS4, WiiU, X360 и XOne.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# К сожалению, на этом графике видны только выбросы, и совсем не видны медиана и 75% квантиль. Для более обоснованных выводов cтоит добавить второй вид, с другим масштабом по оси y, где будет отображена только нижняя часть boxplot-ов
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил.

# %% [markdown]
# # example 1

# %% [markdown]
# #### example 3

# %% [markdown]
# ##### example 4

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %% [markdown]
# ### Влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# рассмотрим платформу PS4
ps4_games = actual_games.query('platform == "ps4"')
ps4_games = ps4_games.sort_values('user_score',ascending = False)

ps4_user_score = sns.scatterplot(data = ps4_games, x = 'user_score',y = 'total_sales')

# здесь не хватает подписей
ps4_user_score.set_xlabel('Оценка пользователей')
ps4_user_score.set_ylabel('Глобальные продажи')
# Out:
# Text(0, 0.5, 'Глобальные продажи')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит за счет комментариев увеличивать ширину строки__
#
# В виде комментариев к коду стоит писать пояснения, почему применили те или иные методы python, зачем сгруппировали данные, для чего нужны срезы и т.д.
#
# Все остальное — выводы, рекомендации, принятые решения, указание на обнаруженные аномалии, анализ графиков и т.д. нужно писать в ячейках markdown. Так твой проект будет проще читать.
#
# Пожалуйста, воспользуйся методичкой по оформлению проектов, чтобы исправить эти недостатки. Ее можно найти в блоке курса: Полезные инструкции для учёбы - Оформление проекта - Рекомендации по выполнению проектов

# %%
ps4_games = ps4_games.query('user_score != -1')
ps4_games = ps4_games.query('total_sales != -1')
ps4_games
# Out:
#                               name platform  year_of_release         genre  \
# 303       the witcher 3: wild hunt      ps4             2015  Role-Playing
# 1107                dark souls iii      ps4             2016  Role-Playing
# 8886      the king of fighters xiv      ps4             2016      Fighting
# 5120                 rocket league      ps4             2016        Sports
# 4676          farming simulator 17      ps4             2016    Simulation
# ...                            ...      ...              ...           ...
# 16486           super dungeon bros      ps4             2016        Action
# 15734  prototype: biohazard bundle      ps4             2016        Action
# 7296         angry birds star wars      ps4             2013      Strategy
# 12756         rugby world cup 2015      ps4             2015        Sports
# 7479      tony hawk's pro skater 5      ps4             2015        Sports
#
# ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# посчитаем корреляцию между отзывами и продажами
ps4_games['user_score'].corr(ps4_games['total_sales'])


# ну и кста. вот в задании тип внутри одной платформы.
# может стоит рассмотреть несколько самых популярных платформ по отедльности?
# тип глянуть для пс4, хбох и ПК, вдруг где-то есть корреляция
# Out:
# -0.031957110204556445

# %%
platform = ['ps4', 'xone', 'pc']
for i in platform:
    games_platform = actual_games.query('platform == @i and user_score != -1 and total_sales != -1')
    correlation = games_platform["user_score"].corr(games_platform["total_sales"])
    print(f'Корреляция для {i}: {correlation}')
# Out:
# Корреляция для ps4: -0.03195711020455644
# Корреляция для xone: -0.06892505328279418
# Корреляция для pc: -0.0489668323351196

# %%
# аналогично для оценок критиков
for i in platform:
    games_platform = actual_games.query('platform == @i and critic_score != -1 and total_sales != -1')
    correlation = games_platform["critic_score"].corr(games_platform["total_sales"])
    print(f'Корреляция для {i}: {correlation}')
# Out:
# Корреляция для ps4: 0.40656790206178123
# Корреляция для xone: 0.41699832800840153
# Корреляция для pc: 0.3141847396903633

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит избавиться от любых видов заглушек при расчете коэф. корреляции и строительстве графиков (нулевых, отрицательных, положительных)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил.

# %% [markdown]
# Отзывы практически никак не влияют на продажи, корреляция близка к нулевому значению

# %%
ps4_games = ps4_games.query('critic_score != -1')
ps4_games = ps4_games.query('total_sales != -1')
ps4_games
# Out:
#                               name platform  year_of_release         genre  \
# 303       the witcher 3: wild hunt      ps4             2015  Role-Playing
# 1107                dark souls iii      ps4             2016  Role-Playing
# 8886      the king of fighters xiv      ps4             2016      Fighting
# 5120                 rocket league      ps4             2016        Sports
# 4676          farming simulator 17      ps4             2016    Simulation
# ...                            ...      ...              ...           ...
# 16486           super dungeon bros      ps4             2016        Action
# 15734  prototype: biohazard bundle      ps4             2016        Action
# 7296         angry birds star wars      ps4             2013      Strategy
# 12756         rugby world cup 2015      ps4             2015        Sports
# 7479      tony hawk's pro skater 5      ps4             2015        Sports
#
# ...

# %%
# посчитаем корреляцию между оценками критиков и продажами
ps4_games['critic_score'].corr(ps4_games['total_sales'])
# Out:
# 0.40589480145836637

# %% [markdown]
# Корреляция продаж с оценкой критиков, в свою очередь, увеличивается относительно оценок пользователей, но все так же мала для поиска прямой связи.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         0.22652606614612342

# %%
ps4_critic_score = sns.scatterplot(data = ps4_games, x = 'critic_score',y = 'total_sales')
plt.title('Взаимосвязь оценок критиков и продаж')
plt.xlabel('Оценка')
plt.ylabel('Количество продаж')
plt.show()

# %%
# посмотрим, как обстоят дела на других платформах
ps3_games = actual_games.query('platform == "ps3"')
ps3_games = ps3_games.sort_values('user_score',ascending = False)
display(ps3_games['user_score'].corr(ps3_games['total_sales']))
display(ps3_games['critic_score'].corr(ps3_games['total_sales']))
# Out:
# 0.23310265851047404
# 0.32459721041912704

# %%
XOne_games = actual_games.query('platform == "xone"')
XOne_games = XOne_games.sort_values('user_score',ascending = False)
display(XOne_games['user_score'].corr(XOne_games['total_sales']))
display(XOne_games['critic_score'].corr(XOne_games['total_sales']))
# Out:
# 0.12171152458232892
# 0.2737821726170211

# %% [markdown]
# Прямой зависимости по-прежнему нет. Также стоит отметить, что оценка критиков в положительном контексте влияет сильнее оценок обычных пользователей на всех платформах.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# ### Общее распределение игр по жанрам

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
popular_genre = actual_games.groupby('genre').agg({'name':'count'}).reset_index()
popular_genre = popular_genre.sort_values(by='name', ascending=False)


# здесь бы подошла кругоая диаграмма
plt.figure(figsize=(8, 8))
plt.pie(popular_genre['name'], labels=popular_genre['genre'], autopct='%1.1f%%', startangle=140)
plt.title('Доля продаж по жанрам')
plt.show()

# %% [markdown]
# С двухкратным отрывом от ближайшего преследователя выделяется жанр Action, после чего идут Sports и Misc.

# %%
actual_games.boxplot(column = ['total_sales'],by = ['genre'],figsize=(16, 8))
plt.ylim([0, 3])
plt.title('Продажи')
plt.xlabel('Жанр')
plt.show()

# %%
# для нижней части boxplot-ов
actual_games.boxplot(column = ['total_sales'],by = ['genre'],figsize=(16, 8))
plt.ylim([0, 1])
plt.title('Продажи')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# Медиана продаж выше всех у жанра Shooter, дальше примерно на одном уровне Sports, Action, Platform и Fighting. Отметим большое количество выбросов, особенно выделяется жанр Action, благодаря чему итоговая вырчка по продажам в этом жанре больше остальных.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# К сожалению, на этом графике видны только выбросы, и совсем не видны медиана и 75% квантиль. Для более обоснованных выводов cтоит добавить второй вид, с другим масштабом по оси y, где будет отображена только нижняя часть boxplot-ов
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил.

# %% [markdown]
# ### Промежуточные итоги
# Провели исследовательский анализ данных: посмотрели, как менялись продажи по платформам, выбрали платформы с наибольшими суммарными продажами, определили актуальный период данных (с 2005 года), посмотрели на продажи актуальных данных, определили, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков (фактически не влияют), нашли самые прибыльные жанры (выделяется Action).

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Промежуточные выводы отлично помогают составить итоговый и не упустить детали на проекте, молодец
#
# стоит поправить нюансы

# %% [markdown]
# ## Портрет пользователя каждого региона

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Тут я нахуевертил брат</b></font>

# %%
# аналогично ниже с жанрами и рейтингом

regions = ['na_sales', 'eu_sales', 'jp_sales']

for region in regions:
    top_platforms = actual_games.groupby(by='platform')[region].sum().sort_values(ascending=False).head(5)
    
    plt.figure(figsize=(8, 8))
    plt.pie(top_platforms, labels=top_platforms.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'Доля продаж по топовым платформам в регионе {region}')
    plt.show()

# %%
# посмотрим на самые популярные платформы в каждом регионе
actual_games.groupby(by='platform').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Популярные платформы региона NA')
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.show()

# %%
actual_games.groupby(by='platform').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Популярные платформы региона EU')
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.show()

# %%
actual_games.groupby(by='platform').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Популярные платформы региона JP')
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# В Европе и Северной Америке в топе платформы X360, Wii и PS3, предпочтения пользователей в целом схожи, а вот Япония выделяется существенным лидерством платформы DS и отсутствием в топе продаж X360.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 2005 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %%
# посмотрим на самые популярные жанры в каждом регионе
actual_games.groupby(by='genre').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Популярные жанры региона NA')
plt.xlabel('Жанр')
plt.ylabel('Продажи')
plt.show()

# %%
actual_games.groupby(by='genre').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Популярные жанры региона EU')
plt.xlabel('Жанр')
plt.ylabel('Продажи')
plt.show()

# %%
actual_games.groupby(by='genre').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Популярные жанры региона JP')
plt.xlabel('Жанр')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  развернуть график в горизонтальные бары, если надписи оси Х не умещаются в горизонтальном виде

# %% [markdown]
# В Северной Америке и Европе пропорция популярных жанров практичеки скопирована друг с друга - в лидерах Action, Sports, Shooter и Misc. Япония опять выделяется. Action, Misc и Sports в топе присутствуют, но с большим отставанием от Role-Playing, видимо, в Японии предпочитают ролевые модели игр.

# %%
# посмотрим на влияние рейтинга ESRB на продажи в отдельном регионе
actual_games.groupby(by='rating').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Влияние рейтинга ESRB на продажи в NA')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи')
plt.show()

# %%
actual_games.groupby(by='rating').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Влияние рейтинга ESRB на продажи в EU')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи')
plt.show()

# %%
actual_games.groupby(by='rating').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='barh')
plt.title('Влияние рейтинга ESRB на продажи в JP')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# В Северной Америке и Европе картина опять идентичная. В лидерах игры рейтинга Е (для всех пользователей), М (для взрослых), T (для подростков) и без рейтинга.
# В Японии подавляющее число отдает предпочтение играм без рейтинга ESRB. Возможно, на азиатском рынке существует свой аналог ESRB или другая система рейтинга, соответственно, рейтинг существует далеко не для всех игр и пользователи обходятся без этого.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Заполнение пропусков в рейтинге позволило определить отличия региональных рынков, молодец

# %% [markdown]
# ### Промежуточные итоги
# Определили для пользователя каждого региона (NA, EU, JP):
#
# Самые популярные платформы (топ-5).
#
# Самые популярные жанры (топ-5).
#
# Влияние рейтинга ESRB на продажи в отдельном регионе?
#
# В каждом исследуемом пункте Северная Америка и Европа фактически копируют друг друга, а Япония отдает предпочтение чему-то другому.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Избавимся от заглушек в пользовательском рейтинге.

# %%
actual_games = actual_games.query('user_score != -1')
actual_games
# Out:
#                                     name platform  year_of_release     genre  \
# 16                    grand theft auto v      ps3             2013    Action
# 23                    grand theft auto v     x360             2013    Action
# 29        call of duty: modern warfare 3     x360             2011   Shooter
# 34            call of duty: black ops ii      ps3             2012   Shooter
# 35            call of duty: black ops ii     x360             2012   Shooter
# ...                                  ...      ...              ...       ...
# 16654                 ben 10 omniverse 2     x360             2013    Action
# 16660                   prison architect     xone             2016    Action
# 16692  metal gear solid v: ground zeroes       pc             2014    Action
# 16696                             breach       pc             2011   Shooter
# 16702            storm: frontline nation       pc             2011  Strategy
#
# ...

# %% [markdown]
# ### Первая гипотеза

# %% [markdown]
# Первая гипотеза звучит так - "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые";
#
# Сформулируем нулевую и альтернативную гипотезы следующим образом:
#
# Н0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# H1: Средние пользовательские рейтинги платформ Xbox One и PC различаются
#
# Используем t-критерий Стьюдента, так как выборки не зависят друг от друга.
# Зададим пороговое значение alpha = 0.05.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
xbox_one = actual_games.loc[actual_games.platform == 'xone', 'user_score'] 
pc = actual_games.loc[actual_games.platform == 'pc', 'user_score'] 

results = st.ttest_ind(xbox_one, 
                       pc)

alpha = 0.05
                       
print(results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 0.6267602271422398
# Не удалось отвергнуть нулевую гипотезу

# %%
xbox_one.mean()
# Out:
# 6.521428571428572

# %%
pc.mean()
# Out:
# 6.451791530944625

# %% [markdown]
# Полученное значение p-value меньше заданного уровня значимости, поэтому можно отвергнуть нулевую гипотезу. Есть основания говорить, что средние пользовательские рейтинги платформ Xbox One и PC различаются.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Самое важное —__ стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.004310919885130945

# %% [markdown]
# ### Вторая гипотеза

# %% [markdown]
# Вторая гипотеза звучит так - "Средние пользовательские рейтинги жанров Action и Sports разные";
#
# Сформулируем нулевую и анльтернативную гипотезы следующим образом:
#
# Н0: Средние пользовательские рейтинги жанров Action и Sports одинаковые
#
# H1: Средние пользовательские рейтинги жанров Action и Sports различаются
#
# Также используем t-критерий Стьюдента, так как выборки не зависят друг от друга. Зададим пороговое значение alpha = 0.05.

# %%
action = actual_games.loc[actual_games.genre == 'Action', 'user_score'] 
sports = actual_games.loc[actual_games.genre == 'Sports', 'user_score'] 

results = st.ttest_ind(action, 
                       sports)

alpha = 0.05
                       
print(results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 6.700647490667088e-24
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Самое важное —__ стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов

# %%
action.mean()
# Out:
# 6.775903614457831

# %%
sports.mean()
# Out:
# 5.651428571428571

# %% [markdown]
# Полученное значение p-value меньше заданного уровня значимости, поэтому также можно отвергнуть нулевую гипотезу. Есть основания говорить, что средние пользовательские рейтинги жанров Action и Sports различаются.

# %% [markdown]
# ### Промежуточные итоги
# Проверили две гипотезы:
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые - отвергли нулевую гипотезу, рейтинги различаются.
#
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные - отвергли нулевую гипотезу о равенстве рейтингов, рейтинги также различаются.

# %% [markdown]
# ## Итоговый вывод

# %% [markdown]
# Загрузили датафрейм с информацией о компьютерных играх, оценках, рейтингах, платформах и жанрах.
#
# Подготовили данные, а именно привели названия к нижнему регистру, преобразовали данные в нужные типы, обработали пропуски и посчитали суммарные продажи во всех регионах, записав их в отдельный столбец.
#
# Во время исследовательского анализа данных выяснили, сколько игр выпускалось в разные годы. До 1995 года игры практически не выпускались. Далее с развитием прогресса и освоением новых технологий наметился ежегодный рост выпуска игр, произошел резкий скачок в 2002-2003 годах и абсолютный пик в 2009. Это объясняется развитием других технологий, в том числе мобильных, которые заставляют потребителей переходить на новые платформы.
#
# Выяснили, как менялись продажи по платформам. Характерный срок жизни одной платформы около 10 лет и все лидирующие платформы теряли динамику продаж и к 2016 году уступили место более современным консолям. Определили актуальный период имеющихся данных для прогноза на следующие периоды. Актуальными мы посчитали данные, начиная с 2005 года, так как в это время были представлены все самые популярные консоли за все время.
#
# Практически все платформы потеряли свою актуальность к 2016 году, дальнейшие перспективы отметили у PS4 и XOne.
#
# Выяснили, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков - прямой зависимости не обнаружили, нашли самые прибыльные жанры (в положительном контексте выделился жанр Action).
#
# После исследовательского анализа составили портрет пользователя каждого региона.
# По каждому исследуемому пункту Северная Америка и Европа практически полностью совпадают, а Япония выделяется каким-то одним объектом исследования, будь то платформа или же жанр.
#
# Соответственно, для Северной Америки: в топе платформы X360, Wii и PS3, среди жанров в лидерах Action, Sports, Shooter и Misc с рейтингами Е (для всех пользователей), М (для взрослых), T (для подростков).
#
# Для Европы: также в лидерах платформы X360, Wii и PS3, жанры Action, Sports, Shooter и Misc с рейтингами Е (для всех пользователей), М (для взрослых), T (для подростков).
#
# Япония, как мы уже заметили, выделяется: весомое лидерство платформы DS и отсутствие в топе продаж X360, жанры Action, Misc и Sports в топе также присутствуют, но с большим отставанием от Role-Playing. Что касается рейтинга, в Японии большинство пользователей отдает предпочтение играм без рейтинга ESRB. Это связано с тем, что, вероятно, на азиатском рынке существует свой аналог ESRB или другая система рейтинга, соответственно, рейтинг существует далеко не для всех игр и пользователи обходятся без этого.
#
#
# Проверили несколько гипотез, из которых следует, что мы можем говорить, что средние пользовательские рейтинги платформ Xbox One и PC различаются, а также, что средние пользовательские рейтинги жанров Action и Sports различаются. Так как полученные значения p-value меньше заданного уровня значимости и нулевые гипотезы о равенстве рейтингов отвергаются.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно обновить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + выполнить проверку на дублирование записей
#  + самое важное — переопределить актуальный период
#  + добавить второй вид диаграммф размаха для платформ и жанров
#  + поправить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез подправить выборки плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
# Плюс
#
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
